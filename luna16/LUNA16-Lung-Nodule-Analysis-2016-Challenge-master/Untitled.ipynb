# %%
import torch 
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
somelist=[]
aaa=torch.randn(1,128)
bbb=torch.randn(1,128)
aaa=aaa.flatten().tolist()
bbb=bbb.flatten().tolist()
somelist.append(aaa)
somelist.append(bbb)
somelist=np.array(somelist)
print(somelist.shape)
neigh = KNeighborsClassifier(n_neighbors=1)
neigh.fit(somelist, y)
# Out:
# (2, 128)
# KNeighborsClassifier(n_neighbors=1)

# %%
aaa=[1,2,3]
bbb=[1,1,4]
c=[aaa[i]==bbb[i] for i in range(min(len(aaa),len(bbb)))]

# %%
np.sum(c)
# Out:
# 1

# %%
test=np.load('/Users/chromium/Desktop/experiment record/test_accuracy_list_agb=32.npy')
train=np.load('/Users/chromium/Desktop/experiment record/train_accuracy_list_agb=32.npy')
val = np.load('/Users/chromium/Desktop/experiment record/val_accuracy_list_agb=32.npy')
epoch=np.arange(40)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
plt.plot(epoch,train,label="train")
plt.plot(epoch,val,label="val")
plt.plot(epoch,test,label='test')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import torch 
import numpy as np

test=np.load('/Users/chromium/Desktop/experiment record/accuracy_list.npy')
print(test[40])


dataframe = pd.DataFrame({'acc': test})
dataframe.to_csv("acc.csv", index=False, sep=',')
epoch=np.arange(83)

# plt.figure(figsize=(10,5))
# plt.plot(epoch,test,label='test')
# plt.legend()
# plt.show()
# Out:
# 0.4646840148698885

# %%
import torch.nn as nn


m = nn.BatchNorm1d(100)
# Without Learnable Parameters
m = nn.BatchNorm1d(100, affine=False)
input = torch.randn(2, 100)
output = m(input)

# %%
output.shape
# Out:
# torch.Size([2, 100])

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df1 = pd.read_csv('/Users/chromium/Desktop/experiment record/run-version_0-tag-train_loss_epoch.csv')
df2 = pd.read_csv('/Users/chromium/Desktop/experiment record/run-version_0-tag-val_loss_epoch.csv')

# %%
plt.figure(figsize=(8,5))
plt.plot(df1['Step'],df1['Value'],label='train',color='orangered')
plt.legend(fontsize=16)
plt.xlabel('iteration',fontsize=16)
plt.ylabel('loss',fontsize=16)
plt.grid()
plt.show()

# %%
df3 = pd.read_csv('/Users/chromium/Desktop/experiment record/run-default_version_2-tag-train_loss_epoch.csv')

# %%
plt.figure(figsize=(8,5))
plt.plot(df3['Step'],df3['Value'],label='train',color='orangered')
plt.legend()
plt.grid()
plt.show()

# %%
df4 = pd.read_csv('/Users/chromium/Desktop/experiment record/test1.csv')

# %%
plt.figure(figsize=(8,5))
plt.plot(df4['Step'],df4['Value'],label='train',color='orangered')
plt.legend(fontsize=16)
plt.xlabel('iteration',fontsize=16)
plt.ylabel('loss',fontsize=16)
plt.grid()
plt.show()

# %%
acc = pd.read_csv('/Users/chromium/Desktop/experiment record/acc1.csv')
epoch=np.arange(0,136,2)

plt.figure(figsize=(8,5))
plt.plot(epoch,acc['trainacc'],label='train',color='orangered')
plt.plot(epoch,acc['testacc'],label='validation')
plt.legend(fontsize=16)
plt.grid()
plt.xlabel('epoch',fontsize=16)
plt.ylabel('accuracy',fontsize=16)
plt.show()

# %%
ggg=np.arange(0,166,2)

# %%
ggg.shape
# Out:
# (83,)
